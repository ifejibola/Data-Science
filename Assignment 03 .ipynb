# %%
Paul Ajibola
Assignment 01 - 2020-10-12
# Out:
#   File "<ipython-input-1-72270fba9de7>", line 1
#     Paul Ajibola
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np

# %%
myDF = pd.read_csv('test.csv')
print(myDF)
# Out:
#        10    192    50   F  NXEYEM
# 0      10  100.0  12.0  45    PAUL
# 1      20  299.0  21.0   M  VNFKZD
# 2      30  378.0  28.0   X  IMGMFY
# 3      40  156.0  44.0   Q  RHRHJY
# 4      50  468.0  33.0   J  HPQCMC
# ..    ...    ...   ...  ..     ...
# 946  9460  136.0  12.0   C  HGVBPV
# 947  9470  316.0  46.0   L  SHBAUD
# 948  9480  461.0  46.0   K  PUZUVO
# 949  9490  185.0  13.0   N  UMESZO
# 950  9500  137.0  10.0   W  JOHHVL
#
# [951 rows x 5 columns]

# %%
myDF.head()
# Out:
#    10    192    50   F  NXEYEM
# 0  10  100.0  12.0  45    PAUL
# 1  20  299.0  21.0   M  VNFKZD
# 2  30  378.0  28.0   X  IMGMFY
# 3  40  156.0  44.0   Q  RHRHJY
# 4  50  468.0  33.0   J  HPQCMC

# %%
newDf = myDF.rename(columns={'10':'ID','192':'Range','50':'Value','F':'Machine Type','NXEYEM':'Zip code'})
newDf.head()
# Out:
#    ID  Range  Value Machine Type Zip code
# 0  10  100.0   12.0           45     PAUL
# 1  20  299.0   21.0            M   VNFKZD
# 2  30  378.0   28.0            X   IMGMFY
# 3  40  156.0   44.0            Q   RHRHJY
# 4  50  468.0   33.0            J   HPQCMC

# %%
checkDFType = newDf.dtypes

# %%
print(checkDFType)
# Out:
# ID               object
# Range           float64
# Value           float64
# Machine Type     object
# Zip code         object
# dtype: object

# %%
selectValue = newDf['Value']
print(selectValue)
# Out:
# 0      12.0
# 1      21.0
# 2      28.0
# 3      44.0
# 4      33.0
#        ...
# 946    12.0
# 947    46.0
# 948    46.0
# 949    13.0
# 950    10.0
# Name: Value, Length: 951, dtype: float64

# %%
newDf.Value
# Out:
# 0      12.0
# 1      21.0
# 2      28.0
# 3      44.0
# 4      33.0
#        ...
# 946    12.0
# 947    46.0
# 948    46.0
# 949    13.0
# 950    10.0
# Name: Value, Length: 951, dtype: float64

# %%
#newDf['Value'] is more object oriented

# %%
#Type of selected column is float 64

# %%
#9 We cannot use both methods for fetching because column name may contain a space in its name

# %%
newDf['Brand'] = newDf['Machine Type'] + " " + newDf['Zip code']

# %%
newDf.head()
# Out:
#    ID  Range  Value Machine Type Zip code     Brand
# 0  10  100.0   12.0           45     PAUL   45 PAUL
# 1  20  299.0   21.0            M   VNFKZD  M VNFKZD
# 2  30  378.0   28.0            X   IMGMFY  X IMGMFY
# 3  40  156.0   44.0            Q   RHRHJY  Q RHRHJY
# 4  50  468.0   33.0            J   HPQCMC  J HPQCMC

# %%
newDf['total'] = newDf['Range'] * newDf['Value']

# %%
newDf.head()
# Out:
#    ID  Range  Value Machine Type Zip code     Brand    total
# 0  10  100.0   12.0           45     PAUL   45 PAUL   1200.0
# 1  20  299.0   21.0            M   VNFKZD  M VNFKZD   6279.0
# 2  30  378.0   28.0            X   IMGMFY  X IMGMFY  10584.0
# 3  40  156.0   44.0            Q   RHRHJY  Q RHRHJY   6864.0
# 4  50  468.0   33.0            J   HPQCMC  J HPQCMC  15444.0

# %%
newDf.describe()
newDf.describe
newDf.shape
newDf.dtypes
# Out:
# ID               object
# Range           float64
# Value           float64
# Machine Type     object
# Zip code         object
# Brand            object
# total           float64
# dtype: object

# %%
newDf.describe()
# Out:
#             Range       Value         total
# count  950.000000  950.000000    950.000000
# mean   297.341053   29.903158   8957.150526
# std    115.955178   12.263832   5267.271725
# min    100.000000   10.000000   1090.000000
# 25%    194.000000   19.000000   4853.750000
# 50%    296.000000   30.000000   7908.000000
# 75%    398.750000   41.000000  12367.750000
# max    500.000000   50.000000  24750.000000

# %%
newDf.describe
# Out:
# <bound method NDFrame.describe of        ID  Range  Value Machine Type Zip code     Brand    total
# 0      10  100.0   12.0           45     PAUL   45 PAUL   1200.0
# 1      20  299.0   21.0            M   VNFKZD  M VNFKZD   6279.0
# 2      30  378.0   28.0            X   IMGMFY  X IMGMFY  10584.0
# 3      40  156.0   44.0            Q   RHRHJY  Q RHRHJY   6864.0
# 4      50  468.0   33.0            J   HPQCMC  J HPQCMC  15444.0
# ..    ...    ...    ...          ...      ...       ...      ...
# 946  9460  136.0   12.0            C   HGVBPV  C HGVBPV   1632.0
# 947  9470  316.0   46.0            L   SHBAUD  L SHBAUD  14536.0
# 948  9480  461.0   46.0            K   PUZUVO  K PUZUVO  21206.0
# 949  9490  185.0   13.0            N   UMESZO  N UMESZO   2405.0
# 950  9500  137.0   10.0            W   JOHHVL  W JOHHVL   1370.0
#
# [951 rows x 7 columns]>

# %%
newDf.shape
# Out:
# (951, 7)

# %%
newDf.dtypes
# Out:
# ID               object
# Range           float64
# Value           float64
# Machine Type     object
# Zip code         object
# Brand            object
# total           float64
# dtype: object

# %%
#describe is the method itself describe() calls the method, and returns the result.

# %%
newID = newDf.rename(columns={'ID':'My ID'})

# %%
newDf.head()
# Out:
#    ID  Range  Value Machine Type Zip code     Brand    total
# 0  10  100.0   12.0           45     PAUL   45 PAUL   1200.0
# 1  20  299.0   21.0            M   VNFKZD  M VNFKZD   6279.0
# 2  30  378.0   28.0            X   IMGMFY  X IMGMFY  10584.0
# 3  40  156.0   44.0            Q   RHRHJY  Q RHRHJY   6864.0
# 4  50  468.0   33.0            J   HPQCMC  J HPQCMC  15444.0

# %%
newID = newDf.rename(columns={'ID':'My ID'}, inplace=True)

# %%
newDf.head()
# Out:
#   My ID  Range  Value Machine Type Zip code     Brand    total
# 0    10  100.0   12.0           45     PAUL   45 PAUL   1200.0
# 1    20  299.0   21.0            M   VNFKZD  M VNFKZD   6279.0
# 2    30  378.0   28.0            X   IMGMFY  X IMGMFY  10584.0
# 3    40  156.0   44.0            Q   RHRHJY  Q RHRHJY   6864.0
# 4    50  468.0   33.0            J   HPQCMC  J HPQCMC  15444.0

# %%
newDf.columns
# Out:
# Index(['My ID', 'Range', 'Value', 'Machine Type', 'Zip code', 'Brand',
#        'total'],
#       dtype='object')

# %%
newDf.columns.str.lower()
# Out:
# Index(['my id', 'range', 'value', 'machine type', 'zip code', 'brand',
#        'total'],
#       dtype='object')

# %%
newDf.columns = newDf.columns.str.lower()
newDf.head()
# Out:
#   my id  range  value machine type zip code     brand    total
# 0    10  100.0   12.0           45     PAUL   45 PAUL   1200.0
# 1    20  299.0   21.0            M   VNFKZD  M VNFKZD   6279.0
# 2    30  378.0   28.0            X   IMGMFY  X IMGMFY  10584.0
# 3    40  156.0   44.0            Q   RHRHJY  Q RHRHJY   6864.0
# 4    50  468.0   33.0            J   HPQCMC  J HPQCMC  15444.0

# %%
newDf.columns = newDf.columns.str.replace(' ','')
newDf.head()
# Out:
#   myid  range  value machinetype zipcode     brand    total
# 0   10  100.0   12.0          45    PAUL   45 PAUL   1200.0
# 1   20  299.0   21.0           M  VNFKZD  M VNFKZD   6279.0
# 2   30  378.0   28.0           X  IMGMFY  X IMGMFY  10584.0
# 3   40  156.0   44.0           Q  RHRHJY  Q RHRHJY   6864.0
# 4   50  468.0   33.0           J  HPQCMC  J HPQCMC  15444.0

# %%
newDf.head()
# Out:
#   myid  range  value machinetype zipcode     brand    total
# 0   10  100.0   12.0          45    PAUL   45 PAUL   1200.0
# 1   20  299.0   21.0           M  VNFKZD  M VNFKZD   6279.0
# 2   30  378.0   28.0           X  IMGMFY  X IMGMFY  10584.0
# 3   40  156.0   44.0           Q  RHRHJY  Q RHRHJY   6864.0
# 4   50  468.0   33.0           J  HPQCMC  J HPQCMC  15444.0

# %%
newDf.drop('brand', axis=1)
# Out:
#      myid  range  value machinetype zipcode    total
# 0      10  100.0   12.0          45    PAUL   1200.0
# 1      20  299.0   21.0           M  VNFKZD   6279.0
# 2      30  378.0   28.0           X  IMGMFY  10584.0
# 3      40  156.0   44.0           Q  RHRHJY   6864.0
# 4      50  468.0   33.0           J  HPQCMC  15444.0
# ..    ...    ...    ...         ...     ...      ...
# 946  9460  136.0   12.0           C  HGVBPV   1632.0
# 947  9470  316.0   46.0           L  SHBAUD  14536.0
# 948  9480  461.0   46.0           K  PUZUVO  21206.0
# 949  9490  185.0   13.0           N  UMESZO   2405.0
# 950  9500  137.0   10.0           W  JOHHVL   1370.0
#
# [951 rows x 6 columns]

# %%
newDf.head()
# Out:
#   myid  range  value machinetype zipcode     brand    total
# 0   10  100.0   12.0          45    PAUL   45 PAUL   1200.0
# 1   20  299.0   21.0           M  VNFKZD  M VNFKZD   6279.0
# 2   30  378.0   28.0           X  IMGMFY  X IMGMFY  10584.0
# 3   40  156.0   44.0           Q  RHRHJY  Q RHRHJY   6864.0
# 4   50  468.0   33.0           J  HPQCMC  J HPQCMC  15444.0

# %%
newDf.drop('brand',inplace=True, axis = 1)

# %%
newDf.head()
# Out:
#   myid  range  value machinetype zipcode    total
# 0   10  100.0   12.0          45    PAUL   1200.0
# 1   20  299.0   21.0           M  VNFKZD   6279.0
# 2   30  378.0   28.0           X  IMGMFY  10584.0
# 3   40  156.0   44.0           Q  RHRHJY   6864.0
# 4   50  468.0   33.0           J  HPQCMC  15444.0

# %%
newDf.drop('total',inplace=True, axis=1)

# %%
newDf.head()
# Out:
#   myid  range  value machinetype zipcode
# 0   10  100.0   12.0          45    PAUL
# 1   20  299.0   21.0           M  VNFKZD
# 2   30  378.0   28.0           X  IMGMFY
# 3   40  156.0   44.0           Q  RHRHJY
# 4   50  468.0   33.0           J  HPQCMC

# %%
newDf.drop([2,4], inplace=True)

# %%
newDf.head()
# Out:
#   myid  range  value machinetype zipcode
# 0   10  100.0   12.0          45    PAUL
# 1   20  299.0   21.0           M  VNFKZD
# 3   40  156.0   44.0           Q  RHRHJY
# 5   60  347.0   38.0           X  XFEWVB
# 6   70  327.0   24.0           F  NLVQPY

# %%
newDf.value.sort_values(ascending=True)
# Out:
# 950    10.0
# 635    10.0
# 648    10.0
# 506    10.0
# 686    10.0
#        ...
# 109    50.0
# 795    50.0
# 631    50.0
# 188    50.0
# 921     NaN
# Name: value, Length: 949, dtype: float64

# %%
newDf.sort_values(by=['myid'])
# Out:
#                              myid  range  value machinetype zipcode
# 921  #Reza Dibaj, ST ID=101280076    NaN    NaN         NaN     NaN
# 0                              10  100.0   12.0          45    PAUL
# 9                             100  347.0   30.0           K  RSVMXY
# 99                           1000  289.0   29.0           G  LCNMXV
# 100                          1010  343.0   21.0           U  WXEISY
# ..                            ...    ...    ...         ...     ...
# 950                          9500  137.0   10.0           W  JOHHVL
# 95                            960  184.0   13.0           F  MHRJTN
# 96                            970  486.0   36.0           W  XVYWMN
# 97                            980  133.0   15.0           T  AJLOVI
# 98                            990  201.0   21.0           Y  TYJAIQ
#
# [949 rows x 5 columns]

# %%
newDf.sort_values(by=['range'],ascending=True, inplace=True)

# %%
newDf.head()
# Out:
#      myid  range  value machinetype zipcode
# 0      10  100.0   12.0          45    PAUL
# 504  5050  100.0   21.0           S  KLYYQV
# 462  4630  101.0   26.0           P  PBJHPM
# 798  7990  101.0   20.0           E  QXAZJW
# 556  5570  102.0   15.0           M  SSGQYR

# %%
newDf = newDf[newDf['range'].between(250, 350)]

# %%
newDf.head()
# Out:
#      myid  range  value machinetype zipcode
# 262  2630  250.0   12.0           O  ZZIXOA
# 57    580  250.0   19.0           K  EFXWGS
